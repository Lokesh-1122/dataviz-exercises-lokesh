# %%
import pandas as pd
df = pd.read_csv('world_happiness_2023 (1).csv')

df.head()
# Out:
#   Country name            Regional indicator  Ladder score  \
# 0      Finland                Western Europe         7.804
# 1      Denmark                Western Europe         7.586
# 2      Iceland                Western Europe         7.525
# 3       Israel  Middle East and North Africa         7.473
# 4  Netherlands                Western Europe         7.464
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     71.9
# 1                 10.933           0.954                     72.7
# 2                 10.878           0.983                     72.5
# 3                 10.527           0.916                     72.4
# 4                 11.015           0.939                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.949       0.142                      0.179
# 1                         0.931       0.168                      0.234
# 2                         0.961       0.260                      0.150
# 3                         0.903       0.149                      0.826
# 4                         0.879       0.240                      0.296

# %%
print(dir(st))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3195/2936286130.py in <cell line: 0>()
# ----> 1 print(dir(st))
#
# NameError: name 'st' is not defined

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")
st.write(f"Data loaded: {len(df)} countries")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3195/3649266911.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import plotly.express as px
#       4
#       5 df = pd.read_csv('../data/world_happiness_2023.csv')
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ── STEP 2: Add a chart + apply appropriate colour rule ───────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

top15 = df.nlargest(15, 'Score').sort_values('Score')

# The bars are ordered, not categorical — sequential blue (light→dark) is appropriate
fig = px.bar(top15, x='Score', y='Country', orientation='h',
             color='Score',
             color_continuous_scale='Blues',
             range_color=[5.0, 8.5],
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})
fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  font=dict(family='Arial', size=12),
                  xaxis=dict(range=[0, 8.5]),
                  coloraxis_showscale=False,
                  margin=dict(l=10,r=20,t=10,b=10))
fig.update_traces(marker_line_width=0)
fig.show()
st.plotly_chart(fig, width='stretch')  # always use this
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3195/1395635268.py in <cell line: 0>()
#       1 # ── STEP 2: Add a chart + apply appropriate colour rule ───────────────────────────
# ----> 2 import streamlit as st
#       3 import pandas as pd
#       4 import plotly.express as px
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ── STEP 3: Sidebar filter + reactive chart ──────────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N countries", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]
top = filtered.nlargest(top_n, 'Score').sort_values('Score')

fig = px.bar(top, x='Score', y='Country', orientation='h',
             color_discrete_sequence=['#2E75B6'],
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})

fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  xaxis=dict(range=[0,8.5], gridcolor='#EEEEEE'),
                  yaxis=dict(showgrid=False),
                  font=dict(family='Arial', size=12),
                  margin=dict(l=10,r=20,t=10,b=10))

fig.update_traces(marker_line_width=0)

st.plotly_chart(fig, width='stretch')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3195/4043424602.py in <cell line: 0>()
#       1 # ── STEP 3: Sidebar filter + reactive chart ──────────────────────────────
# ----> 2 import streamlit as st
#       3 import pandas as pd
#       4 import plotly.express as px
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ── STEP 4: Full dashboard — KPIs + columns layout + BBD colour ──────────
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="World Happiness", page_icon="🌍", layout="wide")

df = pd.read_csv('../data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]

st.title("🌍 World Happiness Dashboard")
st.caption("Source: World Happiness Report 2023 | Kaggle")

# KPI row — BBD: big numbers at the top, readable in 5 seconds
col1, col2, col3 = st.columns(3)
col1.metric("Countries", len(filtered))
col2.metric("Avg Score", f"{filtered['Score'].mean():.2f}",
            f"{filtered['Score'].mean()-df['Score'].mean():+.2f} vs global")
col3.metric("Happiest", filtered.nlargest(1,'Score')['Country'].values[0])

st.divider()

# Two-column layout
col_left, col_right = st.columns(2)

with col_left:
    st.subheader("Rankings")
    top = filtered.nlargest(top_n, 'Score').sort_values('Score')

    fig1 = px.bar(top, x='Score', y='Country', orientation='h',
                  color_discrete_sequence=['#2E75B6'],
                  labels={'Score':'Score (0–10)','Country':''})

    fig1.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       xaxis=dict(range=[0,8.5]), font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    fig1.update_traces(marker_line_width=0)
    st.plotly_chart(fig1, width='stretch')

with col_right:
    st.subheader("Score vs GDP")
    fig2 = px.scatter(filtered, x='GDP', y='Score', hover_name='Country',
                      # BBD categorical colour: continent = unordered group
                      color_discrete_sequence=['#E63946'])
    fig2.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    st.plotly_chart(fig2, width='stretch')

st.divider()
st.caption("Built with Streamlit + Plotly")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3195/722858446.py in <cell line: 0>()
#       4 import plotly.express as px
#       5
# ----> 6 st.set_page_config(page_title="World Happiness", page_icon="🌍", layout="wide")
#       7
#       8 df = pd.read_csv('../data/world_happiness_2023.csv')
#
# NameError: name 'st' is not defined

# %%
import pandas as pd
import plotly.express as px

# Load data
df = pd.read_csv('world_happiness_2023 (1).csv')


# Identify happiness score column
# Replace with actual column name if different
score_col = 'Ladder score'

# Calculate midpoint (global average happiness)
midpoint = df[score_col].mean()

# Difference from midpoint
df['Difference_From_Average'] = df[score_col] - midpoint

# Sort for cleaner visualization
df = df.sort_values('Difference_From_Average')

# Create diverging bar chart
fig = px.bar(
    df,
    x='Country name',
    y='Difference_From_Average',
    color='Difference_From_Average',
    color_continuous_scale='RdBu',
    color_continuous_midpoint=0,
    title='Countries Above and Below the Global Average Happiness Score'
)

# Annotate midpoint
fig.add_annotation(
    x=0.5,
    y=1.08,
    xref='paper',
    yref='paper',
    text=f"Midpoint (Global Average Happiness Score) = {midpoint:.2f}",
    showarrow=False,
    font=dict(size=14)
)

fig.update_layout(
    xaxis_title='Country',
    yaxis_title='Difference from Global Average',
    xaxis_tickangle=-90,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88ae83e1-cbd8-4555-83ca-348371ac5221" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88ae83e1-cbd8-4555-83ca-348371ac5221")) {                    Plotly.newPlot(                        "88ae83e1-cbd8-4555-83ca-348371ac5221",                        [{"alignmentgroup":"True","hovertemplate":"Country name=%{x}\u003cbr\u003eDifference_From_Average=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[-3.951714285714287,-3.418714285714287,-2.8157142857142867,-2.2467142857142868,-2.112714285714287,-1.918714285714287,-1.7747142857142872,-1.6987142857142867,-1.4777142857142866,-1.3797142857142868,-1.3337142857142865,-1.1247142857142869,-1.0367142857142868,-0.9277142857142868,-0.7797142857142871,-0.7377142857142864,-0.6577142857142873,-0.6307142857142871,-0.5707142857142866,-0.5367142857142868,-0.3797142857142868,-0.28271428571428725,-0.21471428571428675,-0.20971428571428685,-0.18371428571428705,-0.011714285714286454,0.0072857142857127855,0.07928571428571285,0.1402857142857128,0.14228571428571346,0.15928571428571292,0.17628571428571327,0.27228571428571335,0.29028571428571315,0.31828571428571273,0.3332857142857133,0.3692857142857129,0.4192857142857136,0.489285714285713,0.654285714285713,0.6822857142857135,0.763285714285713,0.7762857142857129,0.816285714285713,0.8762857142857134,0.8762857142857134,0.8822857142857128,0.9392857142857132,1.0832857142857133,1.1002857142857128,1.1502857142857135,1.284285714285713,1.2862857142857136,1.3122857142857134,1.417285714285713,1.4292857142857134,1.5042857142857136,1.5842857142857127,1.6532857142857136,1.662285714285713,1.7142857142857135,1.7752857142857135,1.9932857142857134],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Afghanistan","Lebanon","Zimbabwe","Ethiopia","Tanzania","Bangladesh","India","Kenya","Uganda","Egypt","Nigeria","Pakistan","Venezuela","Honduras","Morocco","Paraguay","Algeria","Tunisia","Indonesia","South Africa","Bolivia","Ecuador","Peru","Vietnam","Colombia","Serbia","China","Jamaica","South Korea","Philippines","Argentina","Thailand","Brazil","Spain","Japan","Poland","Panama","Estonia","Romania","Uruguay","France","Slovenia","Chile","Lithuania","Belgium","United Kingdom","Czechia","Germany","United States","Ireland","Canada","Australia","Austria","New Zealand","Luxembourg","Switzerland","Norway","Sweden","Netherlands","Israel","Iceland","Denmark","Finland"],"xaxis":"x","y":[-3.951714285714287,-3.418714285714287,-2.8157142857142867,-2.2467142857142868,-2.112714285714287,-1.918714285714287,-1.7747142857142872,-1.6987142857142867,-1.4777142857142866,-1.3797142857142868,-1.3337142857142865,-1.1247142857142869,-1.0367142857142868,-0.9277142857142868,-0.7797142857142871,-0.7377142857142864,-0.6577142857142873,-0.6307142857142871,-0.5707142857142866,-0.5367142857142868,-0.3797142857142868,-0.28271428571428725,-0.21471428571428675,-0.20971428571428685,-0.18371428571428705,-0.011714285714286454,0.0072857142857127855,0.07928571428571285,0.1402857142857128,0.14228571428571346,0.15928571428571292,0.17628571428571327,0.27228571428571335,0.29028571428571315,0.31828571428571273,0.3332857142857133,0.3692857142857129,0.4192857142857136,0.489285714285713,0.654285714285713,0.6822857142857135,0.763285714285713,0.7762857142857129,0.816285714285713,0.8762857142857134,0.8762857142857134,0.8822857142857128,0.9392857142857132,1.0832857142857133,1.1002857142857128,1.1502857142857135,1.284285714285713,1.2862857142857136,1.3122857142857134,1.417285714285713,1.4292857142857134,1.5042857142857136,1.5842857142857127,1.6532857142857136,1.662285714285713,1.7142857142857135, ...

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

st.title("World Happiness Analysis")

df = pd.read_csv("world_happiness_2023.csv")

score_col = 'Ladder score'

midpoint = df[score_col].mean()

df['Difference_From_Average'] = df[score_col] - midpoint
df = df.sort_values('Difference_From_Average')

fig = px.bar(
    df,
    x='Country name',
    y='Difference_From_Average',
    color='Difference_From_Average',
    color_continuous_scale='RdBu',
    color_continuous_midpoint=0,
    title='Countries Above and Below the Global Average Happiness Score'
)

fig.add_annotation(
    x=0.5,
    y=1.08,
    xref='paper',
    yref='paper',
    text=f"Global Average Happiness Score = {midpoint:.2f}",
    showarrow=False
)

st.plotly_chart(fig, use_container_width=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3195/21720036.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import plotly.express as px
#       4
#       5 st.title("World Happiness Analysis")
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
